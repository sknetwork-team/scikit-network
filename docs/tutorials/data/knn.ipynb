# %% [markdown]
# # Building graphs

# %% [markdown]
# Using nearest neighbors algorithms on vector data.

# %%
# %matplotlib inline

import pickle

import networkx as nx

from sknetwork.utils import KNeighborsTransformer, FWKNeighborsTransformer

# %%
iris = pickle.load(open('iris.p', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-0e8924442b66> in <module>
# ----> 1 iris = pickle.load(open('iris.p', 'rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris.p'

# %%
knn = KNeighborsTransformer(n_neighbors=5, undirected=False)
adjacency = knn.fit_transform(iris)

# %%
nx.draw(nx.from_scipy_sparse_matrix(adjacency))

# %%
fwknn = FWKNeighborsTransformer(n_neighbors=2, undirected=True)
adjacency = fwknn.fit_transform(iris)

# %%
nx.draw(nx.from_scipy_sparse_matrix(adjacency))
